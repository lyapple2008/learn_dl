# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

import numpy as np
import csv
import os

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# set a random seed for reproducibility
myseed = 42069
np.random.seed(myseed)
torch.manual_seed(myseed)
if torch.backends.mps.is_available():
    torch.mps.manual_seed(myseed)

# %%
def get_device():
    return 'mps' if torch.backends.mps.is_available() else 'cpu'

def plot_learning_curve(loss_record, title=''):
    ''' Plot learning curve of your DNN (train & dev loss) '''
    total_steps = len(loss_record['train'])
    x_1 = range(total_steps)
    x_2 = x_1[::len(loss_record['train']) // len(loss_record['dev'])]
    figure(figsize=(6, 4))
    plt.plot(x_1, loss_record['train'], c='tab:red', label='train')
    plt.plot(x_2, loss_record['dev'], c='tab:cyan', label='dev')
    plt.ylim(0.0, 5.)
    plt.xlabel('Training steps')
    plt.ylabel('MSE loss')
    plt.title('Learning curve of {}'.format(title))
    plt.legend()
    plt.show()

def plot_pred(dev_set, model, device, lim=35., preds=None, targets=None):
    ''' Plot prediction of your DNN '''
    if preds is None or targets is None:
        model.eval()
        preds, targets = [], []
        for x, y in dev_set:
            x, y = x.to(device), y.to(device)
            with torch.no_grad():
                pred = model(x)
                preds.append(pred.detach().cpu())
                targets.append(y.detach().cpu())
        preds = torch.cat(preds, dim=0).numpy()
        targets = torch.cat(targets, dim=0).numpy()

    figure(figsize=(5, 5))
    plt.scatter(targets, preds, c='r', alpha=0.5)
    plt.plot([-0.2, lim], [-0.2, lim], c='b')
    plt.xlim(-0.2, lim)
    plt.ylim(-0.2, lim)
    plt.xlabel('ground truth value')
    plt.ylabel('predicted value')
    plt.title('Ground Truth v.s. Prediction')
    plt.show()

# %%
class COVID19Dataset(Dataset):
    ''' Dataset for loading and preprocessing the COVID19 dataset '''
    def __init__(self,
                 path,
                 mode='train',
                 target_only=False):
        self.mode = mode

        # Read data into numpy arrays
        with open(path, 'r') as fp:
            data = list(csv.reader(fp))
            data = np.array(data[1:])[:, 1:].astype(float)
        
        if not target_only:
            feats = list(range(93))
        else:
            # TODO: Using 40 states & 2 tested_positive features (indices = 57 & 75)
            feats = list(range(40))
            feats.extend([57,75])
            pass

        if mode == 'test':
            # Testing data
            # data: 893 x 93 (40 states + day 1 (18) + day 2 (18) + day 3 (17))
            data = data[:, feats]
            self.data = torch.FloatTensor(data)
        else:
            # Training data (train/dev sets)
            # data: 2700 x 94 (40 states + day 1 (18) + day 2 (18) + day 3 (18))
            target = data[:, -1]
            data = data[:, feats]
            
            # Splitting training data into train & dev sets
            if mode == 'train':
                indices = [i for i in range(len(data)) if i % 10 != 0]
            elif mode == 'dev':
                indices = [i for i in range(len(data)) if i % 10 == 0]
            
            # Convert data into PyTorch tensors
            self.data = torch.FloatTensor(data[indices])
            self.target = torch.FloatTensor(target[indices])

        # Normalize features (you may remove this part to see what will happen)
        self.data[:, 40:] = \
            (self.data[:, 40:] - self.data[:, 40:].mean(dim=0, keepdim=True)) \
            / self.data[:, 40:].std(dim=0, keepdim=True)

        self.dim = self.data.shape[1]

        print('Finished reading the {} set of COVID19 Dataset ({} samples found, each dim = {})'
              .format(mode, len(self.data), self.dim))

    def __getitem__(self, index):
        # Returns one sample at a time
        if self.mode in ['train', 'dev']:
            # For training
            return self.data[index], self.target[index]
        else:
            # For testing (no target)
            return self.data[index]

    def __len__(self):
        # Returns the size of the dataset
        return len(self.data)

# %%
def prep_dataLoader(path, mode, batch_size, n_job=0, target_only=False):
    ''' Generates a dataset, then is put into a dataLoader. '''
    dataset = COVID19Dataset(path, mode=mode, target_only=target_only)
    dataloader = DataLoader(
        dataset, batch_size,
        shuffle=(mode == 'train'), drop_last=False,
        num_workers=n_job, pin_memory=True)
    return dataloader

# %%
class NeurlNet(nn.Module):
    ''' A simple fully-connected deep neural network '''
    def __init__(self, input_dim) -> None:
        super(NeurlNet, self).__init__()

        self.net = nn.Sequential(
            nn.Linear(input_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 1)
        )

        self.criterion = nn.MSELoss(reduction='mean')

    def forward(self, x):
        return self.net(x).squeeze(1)
    
    def cal_loss(self, pred, target):
        return self.criterion(pred, target)

# %%
# Trainning
def train(tr_set, dv_set, model, config, device):
    n_epochs = config['n_epochs']

    optimizer = getattr(torch.optim, config['optimizer'])(
        model.parameters(), **config['optim_hparas']
    )

    min_mse = 1000.
    loss_record = {'train': [], 'dev': []}
    early_stop_cnt = 0
    epoch = 0
    while epoch < n_epochs:
        model.train()
        for x, y in tr_set:
            optimizer.zero_grad()
            x, y = x.to(device), y.to(device)
            pred = model(x)
            mse_loss = model.cal_loss(pred, y)
            mse_loss.backward()
            optimizer.step()
            loss_record['train'].append(mse_loss.detach().cpu().item())
        
        dev_mse = dev(dv_set, model, device)
        if dev_mse < min_mse:
            min_mse = dev_mse
            print('Saving model (epoch = {:4d}, loss = {:.4f})'.format(epoch + 1, min_mse))
            torch.save(model.state_dict(), config['save_path'])
            early_stop_cnt = 0
        else:
            early_stop_cnt += 1
        
        epoch += 1
        loss_record['dev'].append(dev_mse)
        if early_stop_cnt > config['early_stop']:
            break

    return min_mse, loss_record

# %%
# Validation
def dev(dv_set, model, device):
    model.eval()
    total_loss = 0
    for x, y in dv_set:
        x, y = x.to(device), y.to(device)
        with torch.no_grad():
            pred = model(x)
            mse_loss = model.cal_loss(pred, y)

        total_loss += mse_loss.detach().cpu().item() * len(x)
    total_loss = total_loss / len(dv_set.dataset)

    return total_loss

# %%
# Testing
def test(tt_set, model, device):
    model.eval()
    preds = []
    for x in tt_set:
        x = x.to(device)
        with torch.no_grad():
            pred = model(x)
            preds.append(pred.detach().cpu())
    preds = torch.cat(preds, dim=0).numpy()
    return preds

# %%
# Setup Hyper-parameters
device = get_device()
os.makedirs('models', exist_ok=True)
target_only = False

config = {
    'n_epochs': 3000,
    'batch_size': 270,
    'optimizer': 'SGD',
    'optim_hparas': {
        'lr': 0.001,
        'momentum': 0.9
    },
    'early_stop': 200,
    'save_path': 'models/model.pth'
}

# %%
# Load data
tr_path = './data/covid.train.csv'
tt_path = './data/covid.test.csv'
tr_set = prep_dataLoader(tr_path, 'train', config['batch_size'], target_only=target_only)
dv_set = prep_dataLoader(tr_path, 'dev', config['batch_size'], target_only=target_only)
tt_set = prep_dataLoader(tt_path, 'test', config['batch_size'], target_only=target_only)

# Model
model = NeurlNet(tr_set.dataset.dim).to(device)

# Start Training
model_loss, model_loss_record = train(tr_set, dv_set, model, config, device)
# Out:
# Finished reading the train set of COVID19 Dataset (2430 samples found, each dim = 93)
# Finished reading the dev set of COVID19 Dataset (270 samples found, each dim = 93)
# Finished reading the test set of COVID19 Dataset (893 samples found, each dim = 93)
# Saving model (epoch =    1, loss = 73.5900)
# Saving model (epoch =    2, loss = 61.6326)
# Saving model (epoch =    3, loss = 34.1226)
# Saving model (epoch =    4, loss = 17.6059)
# Saving model (epoch =    5, loss = 11.3656)
# Saving model (epoch =    6, loss = 7.5522)
# Saving model (epoch =    7, loss = 6.2403)
# Saving model (epoch =    8, loss = 5.3865)
# Saving model (epoch =    9, loss = 4.7123)
# Saving model (epoch =   10, loss = 4.1976)
# Saving model (epoch =   11, loss = 3.7770)
# Saving model (epoch =   12, loss = 3.4179)
# Saving model (epoch =   13, loss = 3.1004)
# Saving model (epoch =   14, loss = 2.8777)
# Saving model (epoch =   15, loss = 2.6823)
# Saving model (epoch =   16, loss = 2.5276)
# Saving model (epoch =   17, loss = 2.3583)
# Saving model (epoch =   18, loss = 2.2161)
# Saving model (epoch =   19, loss = 2.0931)
# Saving model (epoch =   20, loss = 1.9826)
# Saving model (epoch =   21, loss = 1.8889)
# Saving model (epoch =   22, loss = 1.7952)
# Saving model (epoch =   23, loss = 1.7239)
# Saving model (epoch =   24, loss = 1.6745)
# Saving model (epoch =   25, loss = 1.6267)
# Saving model (epoch =   26, loss = 1.6197)
# Saving model (epoch =   27, loss = 1.5239)
# Saving model (epoch =   29, loss = 1.4547)
# Saving model (epoch =   30, loss = 1.4301)
# Saving model (epoch =   31, loss = 1.3771)
# Saving model (epoch =   32, loss = 1.3582)
# Saving model (epoch =   33, loss = 1.3147)
# Saving model (epoch =   34, loss = 1.2881)
# Saving model (epoch =   36, loss = 1.2314)
# Saving model (epoch =   37, loss = 1.2069)
# Saving model (epoch =   39, loss = 1.1776)
# Saving model (epoch =   40, loss = 1.1744)
# Saving model (epoch =   41, loss = 1.1548)
# Saving model (epoch =   42, loss = 1.1395)
# Saving model (epoch =   43, loss = 1.1354)
# Saving model (epoch =   44, loss = 1.1184)
# Saving model (epoch =   45, loss = 1.1012)
# Saving model (epoch =   47, loss = 1.0733)
# Saving model (epoch =   49, loss = 1.0651)
# Saving model (epoch =   50, loss = 1.0590)
# Saving model (epoch =   51, loss = 1.0508)
# Saving model (epoch =   52, loss = 1.0475)
# Saving model (epoch =   54, loss = 1.0301)
# Saving model (epoch =   58, loss = 1.0134)
# Saving model (epoch =   60, loss = 1.0118)
# Saving model (epoch =   62, loss = 1.0101)
# Saving model (epoch =   63, loss = 1.0023)
# Saving model (epoch =   65, loss = 0.9946)
# Saving model (epoch =   66, loss = 0.9843)
# Saving model (epoch =   69, loss = 0.9790)
# Saving model (epoch =   71, loss = 0.9713)
# Saving model (epoch =   73, loss = 0.9704)
# Saving model (epoch =   74, loss = 0.9508)
# Saving model (epoch =   77, loss = 0.9436)
# Saving model (epoch =   82, loss = 0.9323)
# Saving model (epoch =   88, loss = 0.9284)
# Saving model (epoch =   90, loss = 0.9234)
# Saving model (epoch =   91, loss = 0.9207)
# Saving model (epoch =   92, loss = 0.9170)
# Saving model (epoch =   95, loss = 0.9143)
# Saving model (epoch =   99, loss = 0.9087)
# Saving model (epoch =  101, loss = 0.8991)
# Saving model (epoch =  104, loss = 0.8983)
# Saving model (epoch =  106, loss = 0.8951)
# Saving model (epoch =  108, loss = 0.8859)
# Saving model (epoch =  114, loss = 0.8744)
# Saving model (epoch =  120, loss = 0.8734)
# Saving model (epoch =  124, loss = 0.8606)
# Saving model (epoch =  136, loss = 0.8584)
# Saving model (epoch =  141, loss = 0.8550)
# Saving model (epoch =  149, loss = 0.8496)
# Saving model (epoch =  155, loss = 0.8486)
# Saving model (epoch =  159, loss = 0.8418)
# Saving model (epoch =  178, loss = 0.8388)
# Saving model (epoch =  180, loss = 0.8371)
# Saving model (epoch =  184, loss = 0.8323)
# Saving model (epoch =  195, loss = 0.8316)
# Saving model (epoch =  198, loss = 0.8233)
# Saving model (epoch =  226, loss = 0.8223)
# Saving model (epoch =  245, loss = 0.8179)
# Saving model (epoch =  248, loss = 0.8163)
# Saving model (epoch =  253, loss = 0.8161)
# Saving model (epoch =  266, loss = 0.8144)
# Saving model (epoch =  268, loss = 0.8142)
# Saving model (epoch =  269, loss = 0.8137)
# Saving model (epoch =  278, loss = 0.8079)
# Saving model (epoch =  282, loss = 0.8058)
# Saving model (epoch =  290, loss = 0.8050)
# Saving model (epoch =  303, loss = 0.8041)
# Saving model (epoch =  317, loss = 0.8037)
# Saving model (epoch =  325, loss = 0.8017)
# Saving model (epoch =  339, loss = 0.7969)
# Saving model (epoch =  360, loss = 0.7932)
# Saving model (epoch =  366, loss = 0.7921)
# Saving model (epoch =  379, loss = 0.7886)
# Saving model (epoch =  530, loss = 0.7864)
# Saving model (epoch =  535, loss = 0.7856)
# Saving model (epoch =  569, loss = 0.7840)
# Saving model (epoch =  647, loss = 0.7819)
# Saving model (epoch =  702, loss = 0.7804)
# Saving model (epoch =  886, loss = 0.7792)

# %%
plot_learning_curve(model_loss_record, title='deep model')


# x_1 = range(12)
# print(x_1)
# x_2 = x_1[::len(x_1)]
# print(x_2)

# %%
del model
model = NeurlNet(tr_set.dataset.dim).to(device)
ckpt = torch.load(config['save_path'], map_location='cpu')
model.load_state_dict(ckpt)
plot_pred(dv_set, model, device)

# %%
def save_pred(preds, file):
    print('Saving results to {}'.format(file))
    with open(file, 'w') as fp:
        writer = csv.writer(fp)
        writer.writerow(['id', 'tested_positive'])
        for i, p in enumerate(preds):
            writer.writerow([i, p])

preds = test(tt_set, model, device)
save_pred(preds, 'pred.csv')
# Out:
# Saving results to pred.csv
